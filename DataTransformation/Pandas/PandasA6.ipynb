# %%
import numpy as np
import pandas as pd

q1 = pd.read_csv("dots.csv")
Q1 = q1["firing_rate"].mean()
Q2 = q1["time"].max()

Q3 = q1.groupby('choice').mean()
Q4 = pd.Series(q1.groupby('align')[['firing_rate']].min())
Q5 = q1.groupby(['align', 'choice'])[['firing_rate']].mean().unstack()
Q6 = q1.pivot_table('firing_rate', index='align', columns='choice')

dfTips = pd.read_csv("tips.csv")
Q7 = dfTips.pivot_table('total_bill', ['sex','smoker'], 'time')
tip = pd.cut(dfTips['tip'], [0,5,10])
Q8 = dfTips.pivot_table('total_bill', ['sex',tip], 'smoker')

Q9 = dfTips.pivot_table(['size', 'tip', 'total_bill'], 'sex', 'smoker', 
                            aggfunc={'size':sum, 'tip':max, 'total_bill':'mean'})

#print(dfTips)
#print(Q9)
print(Q4)

dfTips.combine
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-2fdfe0f45811> in <module>
#       7
#       8 Q3 = q1.groupby('choice').mean()
# ----> 9 Q4 = pd.Series(q1.groupby('align')[['firing_rate']].min())
#      10 Q5 = q1.groupby(['align', 'choice'])[['firing_rate']].mean().unstack()
#      11 Q6 = q1.pivot_table('firing_rate', index='align', columns='choice')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     365             name = ibase.maybe_extract_name(name, data, type(self))
#     366
# --> 367             if is_empty_data(data) and dtype is None:
#     368                 # gh-17261
#     369                 warnings.warn(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/construction.py in is_empty_data(data)
#     819     is_none = data is None
# ...

# %%
import numpy as np
import pandas as pd

s = pd.Series(np.arange(3,12,2))
#print(s)

Q1 = s.values
Q2 = s.keys()
Q3 = s[2]
Q4 = s[2:4]

#print(Q1)
#print(Q2)


d5={"three":3, "five":5, "seven":7, "nine":9, "eleven":11}
Q5 = pd.Series(d5, dtype='int64')
#print(Q5)

d6={'Da':'ta','Sc':'ie', 'nc':'ef', 'or':'all'}
Q6 = pd.Series(d6)
Q7=Q6['nc']
Q8=Q6[1:]
#print(Q8)


sa = pd.Series({'A':'a', 'B':'b', 'C':'c'}, name='lowercase', dtype='object')
sn = pd.Series({'A':1, 'B':2, 'C':3}, name='numbers', dtype = 'int64')
df = pd.DataFrame([sa,sn])
#print(df)
#print('--------------------')

Q9 = df.transpose()
Q10 = Q9.index
Q11 = Q9.columns
Q12 = Q9['numbers']
#print(Q10)
print(Q12)
# Out:
# A    1
# B    2
# C    3
# Name: numbers, dtype: object

# %%
Q10
# Out:
# Index(['A', 'B', 'C'], dtype='object')

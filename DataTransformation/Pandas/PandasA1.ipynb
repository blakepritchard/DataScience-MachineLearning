# %%
import numpy as np
import pandas as pd
Q1 = pd.Series(['Stina Calista', 'Fran Hendrix', 'Cyril Isak', 'Danilo Norina'], index=[5281224 , 4223241, 4233342, 5012332])



Q2={'Roger Clemens': 133.7,
    'Cy Young': 131.5,
    'Walter Johnson': 117.1,
    'Greg Maddux': 116.7,
    'Randy Johnson': 110.4
}
Q3 = pd.Series(Q2)

occupation=pd.Series(['Accountant', 'Data scientist', 'Manager', 'Security staff'], index=[5281224 , 4223241, 4233342, 5012332])
Q4 = pd.DataFrame( {'Name':Q1, 'Occupation': occupation})
Q4

pop_dict = {
'China': 1411778724,
'India': 1378331486,
'United States': 331865271,
'Indonesia': 271350000,
'Pakistan': 225200000
}

area_dict = {
'Russia': 17098246,
'Canada': 9984670,
'China': 9596961,
'United States': 9525067,
'Brazil': 8515767
}

pop_series = pd.Series(pop_dict, dtype='int64')
#print(pop_series)

area_series = pd.Series(area_dict, dtype='int64')
#print(area_series)

Q5 = pd.DataFrame({'Population':pop_series, 'Area':area_series}).sort_values(['Population', 'Area'], ascending=False)
#print(Q5)

Q6 = Q5.loc[['China', 'United States']]
Q7 = Q5.loc[Q5['Population']>270000000]
Q8 = Q5.loc[Q5['Area']>9600000]
# Out:
#                  Population        Area
# China          1.411779e+09   9596961.0
# India          1.378331e+09         NaN
# United States  3.318653e+08   9525067.0
# Indonesia      2.713500e+08         NaN
# Pakistan       2.252000e+08         NaN
# Russia                  NaN  17098246.0
# Canada                  NaN   9984670.0
# Brazil                  NaN   8515767.0

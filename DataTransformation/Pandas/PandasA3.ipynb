# %%
import numpy as np
import pandas as pd

sa = pd.Series({'A':'a', 'B':'b', 'C':'c', 'D':'d', 'E':'e'}, name='lowercase', dtype='object')
sn = pd.Series({'A':1, 'B':2, 'C':3, 'D':4, 'E':5}, name='numbers', dtype = 'int64')
q1 = pd.DataFrame([sa,sn]).transpose()
#q1.index.name='letter' 
##print(q1)
#q1.astype({'numbers':'int64'})
#print(q1.numbers.astype('int64'))

##print('---------------------------')
Q1 = q1.loc['C'].numbers
##print(Q1)

##print('---------------------------')
Q2 = q1.loc['B':]
##print(Q2)

##print('---------------------------')
Q3 = q1.loc['D']
##print(Q3)

#print('Q4 ---------------------------')
Q4 = q1.loc[:'C'].numbers.astype('int64')
#print(Q4)


##print('Q5 ---------------------------')
Q5 = q1.loc[['A','C','D']]
##print(Q5)


##print('Q6 ---------------------------')
Q6 = q1.loc['C']
##print(Q6)

#print('Q7 ---------------------------')
Q7 = q1.loc['E'].numbers
#print(Q7)


##print('Q8 ---------------------------')
Q8 = q1.loc['C':'E']
##print(Q8)

#print('Q9 ---------------------------')
Q9 = q1.loc[q1.numbers<3]
#print(Q9)

#print('Q10 ---------------------------')
Q10 = q1.iloc[3]
#print(Q10)

#print('Q11 ---------------------------')
Q11= q1.iloc[4].numbers
#print(Q11)
#print()

#print('Q12 ---------------------------')
Q12 = q1.iloc[[0,2,3]]
#print(Q12)

#print('Q13 ---------------------------')
Q13 = q1.iloc[2:5]
#print(Q13)

#print('Q14 ---------------------------')
Q14 = q1.iloc[:].lowercase
#print(Q14)

#print('Q15 ---------------------------')
Q15 = q1.assign(percent=lambda x: (x.numbers / sum(x.numbers)).map('{:.6f}'.format))
#print(Q15)
# Out:
# Q4 ---------------------------
# A    1
# B    2
# C    3
# Name: numbers, dtype: int64

# %%
import numpy as np

np.random.seed(56)
Q1=np.random.randint(20, size=(10,10))
#print(Q1)

Q2 = Q1[2:5, 3:8]
#print(Q2)

Q3 = Q1[7:, 4:6]
#print(Q3)

Q4 = Q3.reshape(2,3)
#print(Q4)

x = np.random.randint(15, size=(10))
y = np.random.randint(15, size=(10))
#print(x)
#print(y)

Q5=np.concatenate((x,y))
#print(Q5)

s = np.split(Q5, [4,11,17,22])

Q6a=s[0]
Q6b=s[1] 
Q6c=s[2] 
Q6d=s[3]


#print(Q6a)
#print(Q6b)
#print(Q6c)
#print(Q6d)

Q7=np.sum(Q5)
#print(Q7)

a =np.random.randint(48, 85, size=(50))
Q8=np.mean(a)
#print(Q8)

Q9 = np.array([('Jonathan Loaisiga', 'Baseball player', 595800.00), 
               ('Nick Saban', 'Football coach', 8619934.23), 
               ('Katie Ladecky', 'Swimmer', 100000.00)],
            dtype=[('Name', 'U20'), ('Occupation', 'U20'), ('Salary', 'f8')])
#print(Q9)

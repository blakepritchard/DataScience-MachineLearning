# %%
import numpy as np

np.random.seed(5)
a= np.random.randint(15, size=20)
Q1=a[3]
Q2 = a[8:]
Q3 = a[1:18:2]


np.random.seed(6)
a= np.random.randint(15, size=(7,8))

Q4 =a[5,5]
Q5=a[0:2,5:]


np.random.seed(10)
Q6= np.random.randint(15, size=(4,5))
Q7=Q6[1:,:3]
Q7[1,2]=4


np.random.seed(8)
Q8= np.random.randint(15, size=(4,5))
Q9=Q8[1:,:3].copy()
Q9[1,2]=4


np.random.seed(20)
Q10= np.random.randint(15, size=(2,6)).reshape(4,3)

np.random.seed(15)
Q11=np.random.randint(15, size=(10,1))


np.random.seed(9)
Q12=np.random.randint(15, size=(5,3))[3].copy()


# print(Q12)
# Out:
# [1 6 4]
